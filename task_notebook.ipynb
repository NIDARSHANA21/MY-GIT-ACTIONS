# %% [markdown]
# # My  Jupyter Notebook Task
#
# ## INTRODUCTION
# This is a notebook that demonstrates my skills in ** Markdown formatting**, ** Python coding**and visualization of **Data**.
# The quests are completed step by step below.

# %% [markdown]
# ## Things I would like to learn
# #### -Python coding.
# #### -Maching learning.
# #### -Building web apps.
#
# ---
#
# I want to become **Skilled**, *Confident* and Clear in Coding!

# %% [markdown]
# ## Embed an Image
# Here is an image of **Python**:
#
# ![alt text](https://github.com/NIDARSHANA21/git-task/blob/main/my_image.png?raw=true)

# %% [markdown]
# ## **Example of Code Snippet**
# Here is a sample of code snippet using triple backticks
#
# ```python
# # This is a python code snippet
# x = 3
# y = 5
# printf("Sum:", x+y)

# %% [markdown]
# ---
#
# ### **Code (Variables and Calculations)**
# ```python
# # Python Coding
# # Declare variables and do a calculation
# a = 15
# b = 10
# result = a * b
# print("The result of a * b is:", result)

# %%
import matplotlib.pyplot as plt

# Simple line plot
x = [1, 2, 3, 4, 5]
y = [n**2 for n in x]  # squares

plt.plot(x, y, marker='o')
plt.title("Line Plot of Squares")
plt.xlabel("X values")
plt.ylabel("Y = X^2")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Conclusion
# In this notebook, I practiced:
# - Writing Markdown with headings, bullet lists, formatting, and images
# - Embedding a code snippet
# - Writing Python code for calculations
# - Visualizing data with Matplotlib
#
# This helped me improve my **presentation** and **coding** skills inside Jupyter Notebook.
